# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import root_mean_squared_error
import pickle
from pathlib import Path

DATA_FOLDER = Path("../../../data")
MODEL_FOLDER = Path("../models")
MLFLOW_DB_PATH = Path("..")

# %%
import mlflow

mlflow.set_tracking_uri(f"sqlite:///{MLFLOW_DB_PATH}/mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location=('/Users/alessandro.arlandini/Documents/General DS '
#  'learning/DataTalksClub/mlops-zoomcamp/ale-mlops/notebooks/03-training/experiment_tracking/mlruns/1'), creation_time=1713518478408, experiment_id='1', last_update_time=1713518478408, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet(DATA_FOLDER / "green_tripdata_2021-01.parquet")
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
df["duration"] = (
    df.lpep_dropoff_datetime - df.lpep_pickup_datetime
).dt.total_seconds() / 60

# %%
df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 98%         56.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %%
((df.duration >= 1) & (df.duration <= 60)).mean()
# Out:
# 0.9658903787344154

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]
df.shape
# Out:
# (73908, 21)

# %%
categorical = ["PULocationID", "DOLocationID"]
numerical = ["trip_distance"]
df[categorical] = df[categorical].astype(str)

# %%
dv = DictVectorizer()

train_dicts = df[categorical + numerical].to_dict(orient="records")
X_train = dv.fit_transform(train_dicts)

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=109',
#  'DOLocationID=11',
#  'DOLocationID=111',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=115',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
#  'DOLocationID=140',
#  'DOLocationID=141',
#  'DOLocationID=142',
#  'DOLocationID=143',
#  'DOLocationID=144',
#  'DOLocationID=145',
#  'DOLocationID=146',
#  'DOLocationID=147',
#  'DOLocationID=148',
#  'DOLocationID=149',
#  'DOLocationID=15',
#  'DOLocationID=150',
#  'DOLocationID=151',
#  'DOLocationID=152',
#  'DOLocationID=153',
#  'DOLocationID=154',
#  'DOLocationID=155',
#  'DOLocationID=156',
#  'DOLocationID=157',
#  'DOLocationID=158',
#  'DOLocationID=159',
#  'DOLocationID=16',
#  'DOLocationID=160',
#  'DOLocationID=161',
#  'DOLocationID=162',
#  'DOLocationID=163',
#  'DOLocationID=164',
#  'DOLocationID=165',
#  'DOLocationID=166',
#  'DOLocationID=167',
#  'DOLocationID=168',
#  'DOLocationID=169',
#  'DOLocationID=17',
#  'DOLocationID=170',
#  'DOLocationID=171',
#  'DOLocationID=172',
#  'DOLocationID=173',
#  'DOLocationID=174',
#  'DOLocationID=175',
#  'DOLocationID=177',
#  'DOLocationID=178',
#  'DOLocationID=179',
#  'DOLocationID=18',
#  'DOLocationID=180',
#  'DOLocationID=181',
#  'DOLocationID=182',
#  'DOLocationID=183',
#  'DOLocationID=184',
#  'DOLocationID=185',
#  'DOLocationID=186',
#  'DOLocationID=187',
#  'DOLocationID=188',
#  'DOLocationID=189',
#  'DOLocationID=19',
#  'DOLocationID=190',
#  'DOLocationID=191',
#  'DOLocationID=192',
#  'DOLocationID=193',
#  'DOLocationID=194',
#  'DOLocationID=195',
#  'DOLocationID=196',
#  'DOLocationID=197',
#  'DOLocationID=198',
#  'DOLocationID=2',
#  'DOLocationID=20',
#  'DOLocationID=200',
#  'DOLocationID=201',
#  'DOLocationID=202',
#  'DOLocationID=203',
#  'DOLocationID=205',
#  'DOLocationID=206',
#  'DOLocationID=207',
#  'DOLocationID=208',
#  'DOLocationID=209',
#  'DOLocationID=21',
#  'DOLocationID=210',
#  'DOLocationID=211',
#  'DOLocationID=212',
#  'DOLocationID=213',
#  'DOLocationID=214',
#  'DOLocationID=215',
#  'DOLocationID=216',
#  'DOLocationID=217',
#  'DOLocationID=218',
#  'DOLocationID=219',
#  'DOLocationID=22',
#  'DOLocationID=220',
#  'DOLocationID=221',
#  'DOLocationID=222',
#  'DOLocationID=223',
#  'DOLocationID=224',
#  'DOLocationID=225',
#  'DOLocationID=226',
#  'DOLocationID=227',
#  'DOLocationID=228',
#  'DOLocationID=229',
#  'DOLocationID=23',
#  'DOLocationID=230',
#  'DOLocationID=231',
#  'DOLocationID=232',
#  'DOLocationID=233',
#  'DOLocationID=234',
#  'DOLocationID=235',
#  'DOLocationID=236',
#  'DOLocationID=237',
#  'DOLocationID=238',
#  'DOLocationID=239',
#  'DOLocationID=24',
#  'DOLocationID=240',
#  'DOLocationID=241',
#  'DOLocationID=242',
#  'DOLocationID=243',
#  'DOLocationID=244',
#  'DOLocationID=245',
#  'DOLocationID=246',
#  'DOLocationID=247',
#  'DOLocationID=248',
#  'DOLocationID=249',
#  'DOLocationID=25',
#  'DOLocationID=250',
#  'DOLocationID=251',
#  'DOLocationID=252',
#  'DOLocationID=253',
#  'DOLocationID=254',
#  'DOLocationID=255',
#  'DOLocationID=256',
#  'DOLocationID=257',
#  'DOLocationID=258',
#  'DOLocationID=259',
#  'DOLocationID=26',
#  'DOLocationID=260',
#  'DOLocationID=261',
#  'DOLocationID=262',
#  'DOLocationID=263',
#  'DOLocationID=264',
#  'DOLocationID=265',
#  'DOLocationID=27',
#  'DOLocationID=28',
#  'DOLocationID=29',
#  'DOLocationID=3',
#  'DOLocationID=30',
#  'DOLocationID=31',
#  'DOLocationID=32',
#  'DOLocationID=33',
#  'DOLocationID=34',
#  'DOLocationID=35',
#  'DOLocationID=36',
#  'DOLocationID=37',
#  'DOLocationID=38',
#  'DOLocationID=39',
#  'DOLocationID=4',
#  'DOLocationID=40',
#  'DOLocationID=41',
#  'DOLocationID=42',
#  'DOLocationID=43',
#  'DOLocationID=44',
#  'DOLocationID=45',
#  'DOLocationID=46',
#  'DOLocationID=47',
#  'DOLocationID=48',
#  'DOLocationID=49',
#  'DOLocationID=50',
#  'DOLocationID=51',
#  'DOLocationID=52',
#  'DOLocationID=53',
#  'DOLocationID=54',
#  'DOLocationID=55',
#  'DOLocationID=56',
#  'DOLocationID=57',
#  'DOLocationID=58',
#  'DOLocationID=59',
#  'DOLocationID=6',
#  'DOLocationID=60',
#  'DOLocationID=61',
#  'DOLocationID=62',
#  'DOLocationID=63',
#  'DOLocationID=64',
#  'DOLocationID=65',
#  'DOLocationID=66',
#  'DOLocationID=67',
#  'DOLocationID=68',
#  'DOLocationID=69',
#  'DOLocationID=7',
#  'DOLocationID=70',
#  'DOLocationID=71',
#  'DOLocationID=72',
#  'DOLocationID=73',
#  'DOLocationID=74',
#  'DOLocationID=75',
#  'DOLocationID=76',
#  'DOLocationID=77',
#  'DOLocationID=78',
#  'DOLocationID=79',
#  'DOLocationID=8',
#  'DOLocationID=80',
#  'DOLocationID=81',
#  'DOLocationID=82',
#  'DOLocationID=83',
#  'DOLocationID=84',
#  'DOLocationID=85',
#  'DOLocationID=86',
#  'DOLocationID=87',
#  'DOLocationID=88',
#  'DOLocationID=89',
#  'DOLocationID=9',
#  'DOLocationID=90',
#  'DOLocationID=91',
#  'DOLocationID=92',
#  'DOLocationID=93',
#  'DOLocationID=94',
#  'DOLocationID=95',
#  'DOLocationID=96',
#  'DOLocationID=97',
#  'DOLocationID=98',
#  'PULocationID=10',
#  'PULocationID=100',
#  'PULocationID=101',
#  'PULocationID=102',
#  'PULocationID=106',
#  'PULocationID=107',
#  'PULocationID=108',
#  'PULocationID=11',
#  'PULocationID=112',
#  'PULocationID=113',
#  'PULocationID=114',
#  'PULocationID=115',
#  'PULocationID=116',
#  'PULocationID=117',
#  'PULocationID=118',
#  'PULocationID=119',
#  'PULocationID=12',
#  'PULocationID=120',
#  'PULocationID=121',
#  'PULocationID=122',
#  'PULocationID=123',
#  'PULocationID=124',
#  'PULocationID=125',
#  'PULocationID=126',
#  'PULocationID=127',
#  'PULocationID=128',
#  'PULocationID=129',
#  'PULocationID=13',
#  'PULocationID=130',
#  'PULocationID=131',
#  'PULocationID=132',
#  'PULocationID=133',
#  'PULocationID=134',
#  'PULocationID=135',
#  'PULocationID=136',
#  'PULocationID=137',
#  'PULocationID=138',
#  'PULocationID=139',
#  'PULocationID=14',
#  'PULocationID=140',
#  'PULocationID=141',
#  'PULocationID=142',
#  'PULocationID=143',
#  'PULocationID=144',
#  'PULocationID=145',
#  'PULocationID=146',
#  'PULocationID=147',
#  'PULocationID=148',
#  'PULocationID=149',
#  'PULocationID=15',
#  'PULocationID=150',
#  'PULocationID=151',
#  'PULocationID=152',
#  'PULocationID=153',
#  'PULocationID=154',
#  'PULocationID=155',
#  'PULocationID=156',
#  'PULocationID=157',
#  'PULocationID=158',
#  'PULocationID=159',
#  'PULocationID=16',
#  'PULocationID=160',
#  'PULocationID=161',
#  'PULocationID=162',
#  'PULocationID=163',
#  'PULocationID=164',
#  'PULocationID=165',
#  'PULocationID=166',
#  'PULocationID=167',
#  'PULocationID=168',
#  'PULocationID=169',
#  'PULocationID=17',
#  'PULocationID=170',
#  'PULocationID=171',
#  'PULocationID=172',
#  'PULocationID=173',
#  'PULocationID=174',
#  'PULocationID=175',
#  'PULocationID=176',
#  'PULocationID=177',
#  'PULocationID=178',
#  'PULocationID=179',
#  'PULocationID=18',
#  'PULocationID=180',
#  'PULocationID=181',
#  'PULocationID=182',
#  'PULocationID=183',
#  'PULocationID=184',
#  'PULocationID=185',
#  'PULocationID=186',
#  'PULocationID=187',
#  'PULocationID=188',
#  'PULocationID=189',
#  'PULocationID=19',
#  'PULocationID=190',
#  'PULocationID=191',
#  'PULocationID=192',
#  'PULocationID=193',
#  'PULocationID=194',
#  'PULocationID=195',
#  'PULocationID=196',
#  'PULocationID=197',
#  'PULocationID=198',
#  'PULocationID=20',
#  'PULocationID=200',
#  'PULocationID=201',
#  'PULocationID=202',
#  'PULocationID=203',
#  'PULocationID=205',
#  'PULocationID=206',
#  'PULocationID=207',
#  'PULocationID=208',
#  'PULocationID=209',
#  'PULocationID=21',
#  'PULocationID=210',
#  'PULocationID=211',
#  'PULocationID=212',
#  'PULocationID=213',
#  'PULocationID=214',
#  'PULocationID=215',
#  'PULocationID=216',
#  'PULocationID=217',
#  'PULocationID=218',
#  'PULocationID=219',
#  'PULocationID=22',
#  'PULocationID=220',
#  'PULocationID=221',
#  'PULocationID=222',
#  'PULocationID=223',
#  'PULocationID=224',
#  'PULocationID=225',
#  'PULocationID=226',
#  'PULocationID=227',
#  'PULocationID=228',
#  'PULocationID=229',
#  'PULocationID=23',
#  'PULocationID=230',
#  'PULocationID=231',
#  'PULocationID=232',
#  'PULocationID=233',
#  'PULocationID=234',
#  'PULocationID=235',
#  'PULocationID=236',
#  'PULocationID=237',
#  'PULocationID=238',
#  'PULocationID=239',
#  'PULocationID=24',
#  'PULocationID=240',
#  'PULocationID=241',
#  'PULocationID=242',
#  'PULocationID=243',
#  'PULocationID=244',
#  'PULocationID=245',
#  'PULocationID=246',
#  'PULocationID=247',
#  'PULocationID=248',
#  'PULocationID=249',
#  'PULocationID=25',
#  'PULocationID=250',
#  'PULocationID=252',
#  'PULocationID=253',
#  'PULocationID=254',
#  'PULocationID=255',
#  'PULocationID=256',
#  'PULocationID=257',
#  'PULocationID=258',
#  'PULocationID=259',
#  'PULocationID=26',
#  'PULocationID=260',
#  'PULocationID=261',
#  'PULocationID=262',
#  'PULocationID=263',
#  'PULocationID=264',
#  'PULocationID=265',
#  'PULocationID=27',
#  'PULocationID=28',
#  'PULocationID=29',
#  'PULocationID=3',
#  'PULocationID=31',
#  'PULocationID=32',
#  'PULocationID=33',
#  'PULocationID=34',
#  'PULocationID=35',
#  'PULocationID=36',
#  'PULocationID=37',
#  'PULocationID=38',
#  'PULocationID=39',
#  'PULocationID=4',
#  'PULocationID=40',
#  'PULocationID=41',
#  'PULocationID=42',
#  'PULocationID=43',
#  'PULocationID=44',
#  'PULocationID=45',
#  'PULocationID=46',
#  'PULocationID=47',
#  'PULocationID=48',
#  'PULocationID=49',
#  'PULocationID=50',
#  'PULocationID=51',
#  'PULocationID=52',
#  'PULocationID=53',
#  'PULocationID=54',
#  'PULocationID=55',
#  'PULocationID=56',
#  'PULocationID=57',
#  'PULocationID=58',
#  'PULocationID=59',
#  'PULocationID=60',
#  'PULocationID=61',
#  'PULocationID=62',
#  'PULocationID=63',
#  'PULocationID=64',
#  'PULocationID=65',
#  'PULocationID=66',
#  'PULocationID=67',
#  'PULocationID=68',
#  'PULocationID=69',
#  'PULocationID=7',
#  'PULocationID=70',
#  'PULocationID=71',
#  'PULocationID=72',
#  'PULocationID=73',
#  'PULocationID=74',
#  'PULocationID=75',
#  'PULocationID=76',
#  'PULocationID=77',
#  'PULocationID=78',
#  'PULocationID=79',
#  'PULocationID=8',
#  'PULocationID=80',
#  'PULocationID=81',
#  'PULocationID=82',
#  'PULocationID=83',
#  'PULocationID=84',
#  'PULocationID=85',
#  'PULocationID=86',
#  'PULocationID=87',
#  'PULocationID=88',
#  'PULocationID=89',
#  'PULocationID=9',
#  'PULocationID=90',
#  'PULocationID=91',
#  'PULocationID=92',
#  'PULocationID=93',
#  'PULocationID=94',
#  'PULocationID=95',
#  'PULocationID=96',
#  'PULocationID=97',
#  'PULocationID=98',
#  'trip_distance']

# %% [markdown]
# DictVectorizer transforms data stored in a dictionary into a vector, in this case, a sparse matrix. It recognizes string fields and one-hot encodes them. It also recognizes numerical fields, and leaves them untouched. If we had not converted PULocation and DOLocation to strings, it would have treated them as numerical fields, which would be wrong for our application (as location numbers are only IDs, there is no notion of operation between them).
#
# By checking the values stored in the resulting matrix one can see that except for the duration column, all the other values are 0s and 1s, consistent with the one-hot encoding. The feature names are also consistent with one-hot encoding for the `DOLocationID` and `PULocationID` fields, as every possible value originates a different column.

# %%
np.unique(X_train.toarray()[:, :-1].flatten())
# Out:
# array([0., 1.])

# %%
target = "duration"
y_train = df[target].values

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_train)

# %%
root_mean_squared_error(y_train, y_pred)
# Out:
# 9.838799799829625

# %% [markdown]
# The model predictions have an RMSE of 9.5 minutes. We can probably do better, but this is still the training data. We want to compute scoring metrics on validation data too. Since we will have to repeat pretty much the same steps, we put everything together in functions for convenience.
#
# We are building _preprocessing and training pipelines._

# %%
def read_dataframe(filename):
    categorical = ["PULocationID", "DOLocationID"]

    df = pd.read_parquet(filename)

    df["duration"] = (
        df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    ).dt.total_seconds() / 60
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    df[categorical] = df[categorical].astype(str)

    return df

# %%
# Read training and validation dataframes
df_train = read_dataframe(DATA_FOLDER / "green_tripdata_2021-01.parquet")
df_val = read_dataframe(DATA_FOLDER / "green_tripdata_2021-02.parquet")
df_train.shape, df_val.shape
# Out:
# ((73908, 21), (61921, 21))

# %%
# Engineer an interaction feature
# Interaction features combine two (or more) features into one. The idea is that the pair of values matters more than the single values together.
# In our case we will create an interaction feature from PU and DO. The interpretation is that instead of capturing what is the marginal variation due to "pick up here" and "drop off there" separately, we'll try to capture the information carried by "pick up here and drop off there".
# Note that this also reduces in half the number of features, reducing the variance of the models.
interaction = True

# In this case it suffices to combine the string to create a new categorical feature
if interaction:
    df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
    df_val["PU_DO"] = df_val["PULocationID"] + "_" + df_val["DOLocationID"]

# %%
# Use DictVectorizer to encode categorical features and obtain training and validation matrices
if interaction:
    # When we use the interaction features, we drop the individual features.
    categorical = ["PU_DO"]
else:
    categorical = ["PULocationID", "DOLocationID"]
numerical = ["trip_distance"]

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient="records")
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient="records")
X_val = dv.transform(val_dicts)

# %%
# Obtain training and validation targets
target = "duration"
y_train = df_train[target]
y_val = df_val[target]

# %%
# Train and validate a linear regression model
lm = LinearRegression()
lm.fit(X_train, y_train)

y_pred = lm.predict(X_val)
root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715204520257

# %%
# Train and validate a Lasso model with mlflow logging
with mlflow.start_run():
    mlflow.set_tag("developer", "alessandro")
    mlflow.log_param("train-data-path", DATA_FOLDER / "green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", DATA_FOLDER / "green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)

    ls = Lasso(alpha)
    ls.fit(X_train, y_train)

    y_pred = ls.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# It is common to change the code and try different configurations and parameters while experimenting. When doing that, it's important to record history to allow for proper comparisons, reproducibility and observability.
#
# One simple method of recording what we are doing when training models is to manually log the desired quantities using mlflow. In this case we use the context environment `mlflow.start_run` to record the actions performed by the code in a single experiment run. Then we track:
# * The name of the developer in a tag
# * The hyperparameter `alpha`: this is a parameter that we want to tune, so it's important to keep track of the values we tried.
# * The path to the training and validation data: this is a very simplified method of data versioning. We can do much better than this, but it's a start in pointing to the data used for the run.
# * The resulting RMSE. This is the error metric that we obtain from the model, and it's essential to track it in order to compare runs and find the best one (that with the lowest error).

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
# we use xgb's internal DMatrix to store the data for trainig and cross-validation
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    """Take a set of parameters, train xgboost using those parameters and return
    the RMSE loss obtained with that model."""

    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, "validation")],
            early_stopping_rounds=15,
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {"loss": rmse, "status": STATUS_OK}

# %%
# This is the search space that we want to explore with our (hyper)parameters search
# Hyperopt will loop over all the combinations of parameters that can be generated from this
# parameter space.
search_space = {
    "max_depth": scope.int(hp.quniform("max_depth", 4, 20, 1)),
    # loguniform generates values whose logarithms are uniformly spaced.
    # In this case the logarithms will be -3, -2, -1, 0
    # so the values will be exp(-3), exp(-2), exp(-1), 1
    "learning_rate": hp.loguniform("learning_rate", -3, 0),
    "reg_alpha": hp.loguniform("reg_alpha", -5, -1),
    "reg_lambda": hp.loguniform("reg_lambda", -6, -1),
    "min_child_weight": hp.loguniform("min_child_weight", -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# fmin minimizes a function over a domain, or more precisely finds the minimum value of a function
# over a search space (trying only the inputs specified in the search space).
# By viewing our model as a function (params) -> (loss) we can use fmin to find the set of hyperparameters
# that minimizes the loss, thus finding the best model.
best_result = fmin(
    # we wrote the "objective" function to take a set of hyperparams and returning the loss
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=40,
    # storage for iterations and results
    trials=Trials()
)
# Out:
# [0]	validation-rmse:11.75673
# [1]	validation-rmse:11.33466
# [2]	validation-rmse:10.94414
#   0%|          | 0/40 [00:00<?, ?trial/s, best loss=?]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:06:44] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [3]	validation-rmse:10.58347
# [4]	validation-rmse:10.25118
# [5]	validation-rmse:9.94511
# [6]	validation-rmse:9.66379
# [7]	validation-rmse:9.40561
# [8]	validation-rmse:9.16844
# [9]	validation-rmse:8.95131
# [10]	validation-rmse:8.75266
# [11]	validation-rmse:8.57070
# [12]	validation-rmse:8.40437
# [13]	validation-rmse:8.25221
# [14]	validation-rmse:8.11396
# [15]	validation-rmse:7.98707
# [16]	validation-rmse:7.87161
# [17]	validation-rmse:7.76634
# [18]	validation-rmse:7.67016
# [19]	validation-rmse:7.58359
# [20]	validation-rmse:7.50406
# [21]	validation-rmse:7.43202
# [22]	validation-rmse:7.36617
# [23]	validation-rmse:7.30606
# [24]	validation-rmse:7.25221
# [25]	validation-rmse:7.20330
# [26]	validation-rmse:7.15818
# [27]	validation-rmse:7.11772
# [28]	validation-rmse:7.08035
# [29]	validation-rmse:7.04658
# [30]	validation-rmse:7.01542
# [31]	validation-rmse:6.98764
# [32]	validation-rmse:6.96202
# [33]	validation-rmse:6.93884
# [34]	validation-rmse:6.91751
# [35]	validation-rmse:6.89749
# [36]	validation-rmse:6.87918
# [37]	validation-rmse:6.86279
# [38]	validation-rmse:6.84760
# [39]	validation-rmse:6.83352
# [40]	validation-rmse:6.82093
# [41]	validation-rmse:6.80937
# [42]	validation-rmse:6.79808
# [43]	validation-rmse:6.78828
# [44]	validation-rmse:6.77915
# [45]	validation-rmse:6.77051
# [46]	validation-rmse:6.76230
# [47]	validation-rmse:6.75501
# [48]	validation-rmse:6.74821
# [49]	validation-rmse:6.74194
# [50]	validation-rmse:6.73598
# [51]	validation-rmse:6.73054
# [52]	validation-rmse:6.72568
# [53]	validation-rmse:6.72085
# [54]	validation-rmse:6.71651
# [55]	validation-rmse:6.71225
# [56]	validation-rmse:6.70832
# [57]	validation-rmse:6.70439
# [58]	validation-rmse:6.70094
# [59]	validation-rmse:6.69787
# [60]	validation-rmse:6.69479
# [61]	validation-rmse:6.69240
# [62]	validation-rmse:6.68958
# [63]	validation-rmse:6.68668
# [64]	validation-rmse:6.68449
# [65]	validation-rmse:6.68245
# [66]	validation-rmse:6.68060
# [67]	validation-rmse:6.67899
# [68]	validation-rmse:6.67741
# [69]	validation-rmse:6.67585
# [70]	validation-rmse:6.67461
# [71]	validation-rmse:6.67318
# [72]	validation-rmse:6.67175
# [73]	validation-rmse:6.67022
# [74]	validation-rmse:6.66909
# [75]	validation-rmse:6.66770
# [76]	validation-rmse:6.66696
# [77]	validation-rmse:6.66532
# [78]	validation-rmse:6.66448
# [79]	validation-rmse:6.66338
# [80]	validation-rmse:6.66263
# [81]	validation-rmse:6.66170
# [82]	validation-rmse:6.66093
# [83]	validation-rmse:6.66019
# [84]	validation-rmse:6.65981
# [85]	validation-rmse:6.65923
# [86]	validation-rmse:6.65867
# [87]	validation-rmse:6.65822
# [88]	validation-rmse:6.65750
# [89]	validation-rmse:6.65697
# [90]	validation-rmse:6.65645
# [91]	validation-rmse:6.65599
# [92]	validation-rmse:6.65532
# [93]	validation-rmse:6.65495
# [94]	validation-rmse:6.65423
# [95]	validation-rmse:6.65381
# [96]	validation-rmse:6.65339
# [97]	validation-rmse:6.65244
# [98]	validation-rmse:6.65178
# [99]	validation-rmse:6.65128
# [0]	validation-rmse:10.90317
# [1]	validation-rmse:9.88177
#   2%|▎         | 1/40 [00:03<01:52,  2.87s/trial, best loss: 6.651280016250678]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:06:47] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:9.09541
# [3]	validation-rmse:8.49709
# [4]	validation-rmse:8.04644
# [5]	validation-rmse:7.71006
# [6]	validation-rmse:7.45886
# [7]	validation-rmse:7.27343
# [8]	validation-rmse:7.13699
# [9]	validation-rmse:7.03357
# [10]	validation-rmse:6.95608
# [11]	validation-rmse:6.89827
# [12]	validation-rmse:6.85468
# [13]	validation-rmse:6.82133
# [14]	validation-rmse:6.79526
# [15]	validation-rmse:6.77463
# [16]	validation-rmse:6.75706
# [17]	validation-rmse:6.74321
# [18]	validation-rmse:6.73302
# [19]	validation-rmse:6.72329
# [20]	validation-rmse:6.71537
# [21]	validation-rmse:6.70981
# [22]	validation-rmse:6.70429
# [23]	validation-rmse:6.70010
# [24]	validation-rmse:6.69613
# [25]	validation-rmse:6.69323
# [26]	validation-rmse:6.69096
# [27]	validation-rmse:6.68866
# [28]	validation-rmse:6.68599
# [29]	validation-rmse:6.68403
# [30]	validation-rmse:6.68336
# [31]	validation-rmse:6.68175
# [32]	validation-rmse:6.68028
# [33]	validation-rmse:6.67947
# [34]	validation-rmse:6.67859
# [35]	validation-rmse:6.67836
# [36]	validation-rmse:6.67780
# [37]	validation-rmse:6.67709
# [38]	validation-rmse:6.67611
# [39]	validation-rmse:6.67550
# [40]	validation-rmse:6.67465
# [41]	validation-rmse:6.67403
# [42]	validation-rmse:6.67356
# [43]	validation-rmse:6.67291
# [44]	validation-rmse:6.67233
# [45]	validation-rmse:6.67210
# [46]	validation-rmse:6.67189
# [47]	validation-rmse:6.67157
# [48]	validation-rmse:6.67094
# [49]	validation-rmse:6.67021
# [50]	validation-rmse:6.66981
# [51]	validation-rmse:6.66928
# [52]	validation-rmse:6.66880
# [53]	validation-rmse:6.66843
# [54]	validation-rmse:6.66814
# [55]	validation-rmse:6.66784
# [56]	validation-rmse:6.66708
# [57]	validation-rmse:6.66673
# [58]	validation-rmse:6.66638
# [59]	validation-rmse:6.66613
# [60]	validation-rmse:6.66596
# [61]	validation-rmse:6.66566
# [62]	validation-rmse:6.66549
# [63]	validation-rmse:6.66449
# [64]	validation-rmse:6.66423
# [65]	validation-rmse:6.66352
# [66]	validation-rmse:6.66310
# [67]	validation-rmse:6.66268
# [68]	validation-rmse:6.66250
# [69]	validation-rmse:6.66210
# [70]	validation-rmse:6.66190
# [71]	validation-rmse:6.66164
# [72]	validation-rmse:6.66127
# [73]	validation-rmse:6.66102
# [74]	validation-rmse:6.66088
# [75]	validation-rmse:6.66058
# [76]	validation-rmse:6.66026
# [77]	validation-rmse:6.65983
# [78]	validation-rmse:6.65843
# [79]	validation-rmse:6.65807
# [80]	validation-rmse:6.65793
# [81]	validation-rmse:6.65769
# [82]	validation-rmse:6.65736
# [83]	validation-rmse:6.65734
# [84]	validation-rmse:6.65692
# [85]	validation-rmse:6.65669
# [86]	validation-rmse:6.65645
# [87]	validation-rmse:6.65610
# [88]	validation-rmse:6.65574
# [89]	validation-rmse:6.65579
# [90]	validation-rmse:6.65557
# [91]	validation-rmse:6.65546
# [92]	validation-rmse:6.65517
# [93]	validation-rmse:6.65505
# [94]	validation-rmse:6.65500
# [95]	validation-rmse:6.65477
# [96]	validation-rmse:6.65459
# [97]	validation-rmse:6.65438
# [98]	validation-rmse:6.65420
# [99]	validation-rmse:6.65412
# [0]	validation-rmse:10.21836
#   5%|▌         | 2/40 [00:06<01:55,  3.05s/trial, best loss: 6.651280016250678]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:06:50] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:8.91050
# [2]	validation-rmse:8.07339
# [3]	validation-rmse:7.55109
# [4]	validation-rmse:7.22741
# [5]	validation-rmse:7.02734
# [6]	validation-rmse:6.89884
# [7]	validation-rmse:6.82018
# [8]	validation-rmse:6.76804
# [9]	validation-rmse:6.73511
# [10]	validation-rmse:6.71189
# [11]	validation-rmse:6.69468
# [12]	validation-rmse:6.68351
# [13]	validation-rmse:6.67432
# [14]	validation-rmse:6.66706
# [15]	validation-rmse:6.66214
# [16]	validation-rmse:6.65848
# [17]	validation-rmse:6.65500
# [18]	validation-rmse:6.65349
# [19]	validation-rmse:6.65146
# [20]	validation-rmse:6.64882
# [21]	validation-rmse:6.64717
# [22]	validation-rmse:6.64506
# [23]	validation-rmse:6.64400
# [24]	validation-rmse:6.64179
# [25]	validation-rmse:6.64002
# [26]	validation-rmse:6.63814
# [27]	validation-rmse:6.63668
# [28]	validation-rmse:6.63512
# [29]	validation-rmse:6.63363
# [30]	validation-rmse:6.63253
# [31]	validation-rmse:6.62985
# [32]	validation-rmse:6.62817
# [33]	validation-rmse:6.62739
# [34]	validation-rmse:6.62438
# [35]	validation-rmse:6.62222
# [36]	validation-rmse:6.62034
# [37]	validation-rmse:6.61849
# [38]	validation-rmse:6.61734
# [39]	validation-rmse:6.61597
# [40]	validation-rmse:6.61459
# [41]	validation-rmse:6.61403
# [42]	validation-rmse:6.61153
# [43]	validation-rmse:6.61019
# [44]	validation-rmse:6.60936
# [45]	validation-rmse:6.60814
# [46]	validation-rmse:6.60662
# [47]	validation-rmse:6.60611
# [48]	validation-rmse:6.60461
# [49]	validation-rmse:6.60339
# [50]	validation-rmse:6.60234
# [51]	validation-rmse:6.60220
# [52]	validation-rmse:6.59923
# [53]	validation-rmse:6.59853
# [54]	validation-rmse:6.59793
# [55]	validation-rmse:6.59698
# [56]	validation-rmse:6.59574
# [57]	validation-rmse:6.59471
# [58]	validation-rmse:6.59434
# [59]	validation-rmse:6.59228
# [60]	validation-rmse:6.59138
# [61]	validation-rmse:6.59062
# [62]	validation-rmse:6.58993
# [63]	validation-rmse:6.58938
# [64]	validation-rmse:6.58813
# [65]	validation-rmse:6.58752
# [66]	validation-rmse:6.58582
# [67]	validation-rmse:6.58574
# [68]	validation-rmse:6.58491
# [69]	validation-rmse:6.58333
# [70]	validation-rmse:6.58265
# [71]	validation-rmse:6.58087
# [72]	validation-rmse:6.58013
# [73]	validation-rmse:6.57912
# [74]	validation-rmse:6.57882
# [75]	validation-rmse:6.57822
# [76]	validation-rmse:6.57771
# [77]	validation-rmse:6.57703
# [78]	validation-rmse:6.57676
# [79]	validation-rmse:6.57583
# [80]	validation-rmse:6.57471
# [81]	validation-rmse:6.57372
# [82]	validation-rmse:6.57289
# [83]	validation-rmse:6.57203
# [84]	validation-rmse:6.57127
# [85]	validation-rmse:6.57093
# [86]	validation-rmse:6.57024
# [87]	validation-rmse:6.56903
# [88]	validation-rmse:6.56824
# [89]	validation-rmse:6.56797
# [90]	validation-rmse:6.56708
# [91]	validation-rmse:6.56580
# [92]	validation-rmse:6.56464
# [93]	validation-rmse:6.56433
# [94]	validation-rmse:6.56353
# [95]	validation-rmse:6.56289
# [96]	validation-rmse:6.56250
# [97]	validation-rmse:6.56150
# [98]	validation-rmse:6.56084
# [99]	validation-rmse:6.56078
# [0]	validation-rmse:11.41073
# [1]	validation-rmse:10.71449
# [2]	validation-rmse:10.11192
#   8%|▊         | 3/40 [00:09<01:58,  3.21s/trial, best loss: 6.5607798629559735]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:06:53] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [3]	validation-rmse:9.59319
# [4]	validation-rmse:9.14726
# [5]	validation-rmse:8.76644
# [6]	validation-rmse:8.44241
# [7]	validation-rmse:8.16699
# [8]	validation-rmse:7.93409
# [9]	validation-rmse:7.73767
# [10]	validation-rmse:7.57233
# [11]	validation-rmse:7.43303
# [12]	validation-rmse:7.31556
# [13]	validation-rmse:7.21633
# [14]	validation-rmse:7.13312
# [15]	validation-rmse:7.06284
# [16]	validation-rmse:7.00355
# [17]	validation-rmse:6.95364
# [18]	validation-rmse:6.91117
# [19]	validation-rmse:6.87456
# [20]	validation-rmse:6.84367
# [21]	validation-rmse:6.81726
# [22]	validation-rmse:6.79424
# [23]	validation-rmse:6.77502
# [24]	validation-rmse:6.75812
# [25]	validation-rmse:6.74332
# [26]	validation-rmse:6.73076
# [27]	validation-rmse:6.71977
# [28]	validation-rmse:6.70967
# [29]	validation-rmse:6.70157
# [30]	validation-rmse:6.69333
# [31]	validation-rmse:6.68673
# [32]	validation-rmse:6.68044
# [33]	validation-rmse:6.67477
# [34]	validation-rmse:6.66940
# [35]	validation-rmse:6.66472
# [36]	validation-rmse:6.66038
# [37]	validation-rmse:6.65735
# [38]	validation-rmse:6.65367
# [39]	validation-rmse:6.65058
# [40]	validation-rmse:6.64854
# [41]	validation-rmse:6.64577
# [42]	validation-rmse:6.64402
# [43]	validation-rmse:6.64184
# [44]	validation-rmse:6.64025
# [45]	validation-rmse:6.63883
# [46]	validation-rmse:6.63700
# [47]	validation-rmse:6.63538
# [48]	validation-rmse:6.63433
# [49]	validation-rmse:6.63355
# [50]	validation-rmse:6.63252
# [51]	validation-rmse:6.63183
# [52]	validation-rmse:6.63011
# [53]	validation-rmse:6.62941
# [54]	validation-rmse:6.62846
# [55]	validation-rmse:6.62752
# [56]	validation-rmse:6.62686
# [57]	validation-rmse:6.62530
# [58]	validation-rmse:6.62471
# [59]	validation-rmse:6.62394
# [60]	validation-rmse:6.62314
# [61]	validation-rmse:6.62167
# [62]	validation-rmse:6.62101
# [63]	validation-rmse:6.62038
# [64]	validation-rmse:6.61984
# [65]	validation-rmse:6.61936
# [66]	validation-rmse:6.61872
# [67]	validation-rmse:6.61799
# [68]	validation-rmse:6.61703
# [69]	validation-rmse:6.61642
# [70]	validation-rmse:6.61548
# [71]	validation-rmse:6.61489
# [72]	validation-rmse:6.61456
# [73]	validation-rmse:6.61397
# [74]	validation-rmse:6.61328
# [75]	validation-rmse:6.61254
# [76]	validation-rmse:6.61217
# [77]	validation-rmse:6.61142
# [78]	validation-rmse:6.60992
# [79]	validation-rmse:6.60950
# [80]	validation-rmse:6.60880
# [81]	validation-rmse:6.60821
# [82]	validation-rmse:6.60771
# [83]	validation-rmse:6.60731
# [84]	validation-rmse:6.60663
# [85]	validation-rmse:6.60614
# [86]	validation-rmse:6.60554
# [87]	validation-rmse:6.60498
# [88]	validation-rmse:6.60418
# [89]	validation-rmse:6.60312
# [90]	validation-rmse:6.60275
# [91]	validation-rmse:6.60221
# [92]	validation-rmse:6.60188
# [93]	validation-rmse:6.60118
# [94]	validation-rmse:6.60087
# [95]	validation-rmse:6.60012
# [96]	validation-rmse:6.59961
# [97]	validation-rmse:6.59897
# [98]	validation-rmse:6.59857
# [99]	validation-rmse:6.59742
# [0]	validation-rmse:11.67842
# [1]	validation-rmse:11.19016
#  10%|█         | 4/40 [00:12<01:51,  3.09s/trial, best loss: 6.5607798629559735]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:06:56] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:10.74558
# [3]	validation-rmse:10.34103
# [4]	validation-rmse:9.97349
# [5]	validation-rmse:9.64196
# [6]	validation-rmse:9.34099
# [7]	validation-rmse:9.06954
# [8]	validation-rmse:8.82469
# [9]	validation-rmse:8.60591
# [10]	validation-rmse:8.40782
# [11]	validation-rmse:8.22895
# [12]	validation-rmse:8.06904
# [13]	validation-rmse:7.92709
# [14]	validation-rmse:7.79841
# [15]	validation-rmse:7.68383
# [16]	validation-rmse:7.58121
# [17]	validation-rmse:7.49002
# [18]	validation-rmse:7.40893
# [19]	validation-rmse:7.33484
# [20]	validation-rmse:7.27047
# [21]	validation-rmse:7.21189
# [22]	validation-rmse:7.15841
# [23]	validation-rmse:7.11148
# [24]	validation-rmse:7.06985
# [25]	validation-rmse:7.03192
# [26]	validation-rmse:6.99835
# [27]	validation-rmse:6.96725
# [28]	validation-rmse:6.94056
# [29]	validation-rmse:6.91593
# [30]	validation-rmse:6.89316
# [31]	validation-rmse:6.87273
# [32]	validation-rmse:6.85414
# [33]	validation-rmse:6.83733
# [34]	validation-rmse:6.82271
# [35]	validation-rmse:6.80845
# [36]	validation-rmse:6.79724
# [37]	validation-rmse:6.78624
# [38]	validation-rmse:6.77691
# [39]	validation-rmse:6.76813
# [40]	validation-rmse:6.76045
# [41]	validation-rmse:6.75323
# [42]	validation-rmse:6.74555
# [43]	validation-rmse:6.73940
# [44]	validation-rmse:6.73384
# [45]	validation-rmse:6.72929
# [46]	validation-rmse:6.72430
# [47]	validation-rmse:6.71956
# [48]	validation-rmse:6.71555
# [49]	validation-rmse:6.71169
# [50]	validation-rmse:6.70826
# [51]	validation-rmse:6.70503
# [52]	validation-rmse:6.70220
# [53]	validation-rmse:6.69950
# [54]	validation-rmse:6.69699
# [55]	validation-rmse:6.69467
# [56]	validation-rmse:6.69284
# [57]	validation-rmse:6.69090
# [58]	validation-rmse:6.68892
# [59]	validation-rmse:6.68688
# [60]	validation-rmse:6.68541
# [61]	validation-rmse:6.68396
# [62]	validation-rmse:6.68282
# [63]	validation-rmse:6.68103
# [64]	validation-rmse:6.67987
# [65]	validation-rmse:6.67846
# [66]	validation-rmse:6.67738
# [67]	validation-rmse:6.67633
# [68]	validation-rmse:6.67544
# [69]	validation-rmse:6.67424
# [70]	validation-rmse:6.67336
# [71]	validation-rmse:6.67267
# [72]	validation-rmse:6.67225
# [73]	validation-rmse:6.67198
# [74]	validation-rmse:6.67133
# [75]	validation-rmse:6.67052
# [76]	validation-rmse:6.66992
# [77]	validation-rmse:6.66930
# [78]	validation-rmse:6.66868
# [79]	validation-rmse:6.66804
# [80]	validation-rmse:6.66716
# [81]	validation-rmse:6.66641
# [82]	validation-rmse:6.66585
# [83]	validation-rmse:6.66530
# [84]	validation-rmse:6.66454
# [85]	validation-rmse:6.66379
# [86]	validation-rmse:6.66321
# [87]	validation-rmse:6.66274
# [88]	validation-rmse:6.66250
# [89]	validation-rmse:6.66170
# [90]	validation-rmse:6.66110
# [91]	validation-rmse:6.66060
# [92]	validation-rmse:6.66015
# [93]	validation-rmse:6.65982
# [94]	validation-rmse:6.65925
# [95]	validation-rmse:6.65904
# [96]	validation-rmse:6.65851
# [97]	validation-rmse:6.65793
# [98]	validation-rmse:6.65760
# [99]	validation-rmse:6.65714
# [0]	validation-rmse:10.98884
# [1]	validation-rmse:10.01650
# [2]	validation-rmse:9.25286
# [3]	validation-rmse:8.65614
# [4]	validation-rmse:8.19999
# [5]	validation-rmse:7.84941
#  12%|█▎        | 5/40 [00:17<02:06,  3.63s/trial, best loss: 6.5607798629559735]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:07:01] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [6]	validation-rmse:7.58369
# [7]	validation-rmse:7.38116
# [8]	validation-rmse:7.22660
# [9]	validation-rmse:7.10921
# [10]	validation-rmse:7.01993
# [11]	validation-rmse:6.95261
# [12]	validation-rmse:6.89904
# [13]	validation-rmse:6.85780
# [14]	validation-rmse:6.82672
# [15]	validation-rmse:6.80134
# [16]	validation-rmse:6.78129
# [17]	validation-rmse:6.76507
# [18]	validation-rmse:6.75042
# [19]	validation-rmse:6.73966
# [20]	validation-rmse:6.73116
# [21]	validation-rmse:6.72282
# [22]	validation-rmse:6.71716
# [23]	validation-rmse:6.71128
# [24]	validation-rmse:6.70655
# [25]	validation-rmse:6.70333
# [26]	validation-rmse:6.69869
# [27]	validation-rmse:6.69664
# [28]	validation-rmse:6.69501
# [29]	validation-rmse:6.69165
# [30]	validation-rmse:6.68989
# [31]	validation-rmse:6.68792
# [32]	validation-rmse:6.68587
# [33]	validation-rmse:6.68451
# [34]	validation-rmse:6.68330
# [35]	validation-rmse:6.68251
# [36]	validation-rmse:6.68160
# [37]	validation-rmse:6.68045
# [38]	validation-rmse:6.67914
# [39]	validation-rmse:6.67793
# [40]	validation-rmse:6.67677
# [41]	validation-rmse:6.67598
# [42]	validation-rmse:6.67473
# [43]	validation-rmse:6.67386
# [44]	validation-rmse:6.67090
# [45]	validation-rmse:6.66964
# [46]	validation-rmse:6.66862
# [47]	validation-rmse:6.66761
# [48]	validation-rmse:6.66664
# [49]	validation-rmse:6.66580
# [50]	validation-rmse:6.66478
# [51]	validation-rmse:6.66368
# [52]	validation-rmse:6.66281
# [53]	validation-rmse:6.66180
# [54]	validation-rmse:6.66092
# [55]	validation-rmse:6.66024
# [56]	validation-rmse:6.65968
# [57]	validation-rmse:6.65890
# [58]	validation-rmse:6.65779
# [59]	validation-rmse:6.65704
# [60]	validation-rmse:6.65640
# [61]	validation-rmse:6.65561
# [62]	validation-rmse:6.65502
# [63]	validation-rmse:6.65401
# [64]	validation-rmse:6.65303
# [65]	validation-rmse:6.65084
# [66]	validation-rmse:6.64987
# [67]	validation-rmse:6.64935
# [68]	validation-rmse:6.64852
# [69]	validation-rmse:6.64741
# [70]	validation-rmse:6.64679
# [71]	validation-rmse:6.64562
# [72]	validation-rmse:6.64493
# [73]	validation-rmse:6.64419
# [74]	validation-rmse:6.64338
# [75]	validation-rmse:6.64281
# [76]	validation-rmse:6.64217
# [77]	validation-rmse:6.64138
# [78]	validation-rmse:6.64046
# [79]	validation-rmse:6.64001
# [80]	validation-rmse:6.63930
# [81]	validation-rmse:6.63855
# [82]	validation-rmse:6.63764
# [83]	validation-rmse:6.63625
# [84]	validation-rmse:6.63585
# [85]	validation-rmse:6.63505
# [86]	validation-rmse:6.63437
# [87]	validation-rmse:6.63401
# [88]	validation-rmse:6.63345
# [89]	validation-rmse:6.63311
# [90]	validation-rmse:6.63228
# [91]	validation-rmse:6.63193
# [92]	validation-rmse:6.63131
# [93]	validation-rmse:6.63070
# [94]	validation-rmse:6.63012
# [95]	validation-rmse:6.62925
# ...
# [9]	validation-rmse:9.22154
# [10]	validation-rmse:9.02530
# [11]	validation-rmse:8.84326
# [12]	validation-rmse:8.67464
# [13]	validation-rmse:8.51902
# [14]	validation-rmse:8.37511
# [15]	validation-rmse:8.24226
# [16]	validation-rmse:8.11974
# [17]	validation-rmse:8.00678
# [18]	validation-rmse:7.90260
# [19]	validation-rmse:7.80648
# [20]	validation-rmse:7.71792
# [21]	validation-rmse:7.63651
# [22]	validation-rmse:7.56159
# [23]	validation-rmse:7.49277
# [24]	validation-rmse:7.42925
# [25]	validation-rmse:7.37095
# [26]	validation-rmse:7.31736
# [27]	validation-rmse:7.26769
# [28]	validation-rmse:7.22217
# [29]	validation-rmse:7.18001
# [30]	validation-rmse:7.14159
# [31]	validation-rmse:7.10615
# [32]	validation-rmse:7.07367
# [33]	validation-rmse:7.04383
# [34]	validation-rmse:7.01627
# [35]	validation-rmse:6.99034
# [36]	validation-rmse:6.96703
# [37]	validation-rmse:6.94496
# [38]	validation-rmse:6.92510
# [39]	validation-rmse:6.90610
# [40]	validation-rmse:6.88916
# [41]	validation-rmse:6.87285
# [42]	validation-rmse:6.85789
# [43]	validation-rmse:6.84407
# [44]	validation-rmse:6.83136
# [45]	validation-rmse:6.81954
# [46]	validation-rmse:6.80881
# [47]	validation-rmse:6.79864
# [48]	validation-rmse:6.78891
# [49]	validation-rmse:6.78026
# [50]	validation-rmse:6.77198
# [51]	validation-rmse:6.76416
# [52]	validation-rmse:6.75713
# [53]	validation-rmse:6.75060
# [54]	validation-rmse:6.74446
# [55]	validation-rmse:6.73866
# [56]	validation-rmse:6.73317
# [57]	validation-rmse:6.72828
# [58]	validation-rmse:6.72356
# [59]	validation-rmse:6.71901
# [60]	validation-rmse:6.71472
# [61]	validation-rmse:6.71086
# [62]	validation-rmse:6.70725
# [63]	validation-rmse:6.70350
# [64]	validation-rmse:6.70016
# [65]	validation-rmse:6.69693
# [66]	validation-rmse:6.69382
# [67]	validation-rmse:6.69101
# [68]	validation-rmse:6.68842
# [69]	validation-rmse:6.68588
# [70]	validation-rmse:6.68326
# [71]	validation-rmse:6.68081
# [72]	validation-rmse:6.67851
# [73]	validation-rmse:6.67626
# [74]	validation-rmse:6.67413
# [75]	validation-rmse:6.67239
# [76]	validation-rmse:6.67044
# [77]	validation-rmse:6.66893
# [78]	validation-rmse:6.66748
# [79]	validation-rmse:6.66601
# [80]	validation-rmse:6.66468
# [81]	validation-rmse:6.66328
# [82]	validation-rmse:6.66178
# [83]	validation-rmse:6.66067
# [84]	validation-rmse:6.65944
# [85]	validation-rmse:6.65826
# [86]	validation-rmse:6.65710
# [87]	validation-rmse:6.65612
# [88]	validation-rmse:6.65514
# [89]	validation-rmse:6.65429
# [90]	validation-rmse:6.65337
# [91]	validation-rmse:6.65219
# [92]	validation-rmse:6.65144
# [93]	validation-rmse:6.65061
# [94]	validation-rmse:6.64954
# [95]	validation-rmse:6.64851
# [96]	validation-rmse:6.64793
# [97]	validation-rmse:6.64679
# [98]	validation-rmse:6.64631
# [99]	validation-rmse:6.64553
# [0]	validation-rmse:9.24874
# [1]	validation-rmse:7.83907
# [2]	validation-rmse:7.19832
#  98%|█████████▊| 39/40 [01:57<00:03,  3.62s/trial, best loss: 6.379161457238043]
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [14:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [3]	validation-rmse:6.91707
# [4]	validation-rmse:6.78676
# [5]	validation-rmse:6.72106
# [6]	validation-rmse:6.68491
# [7]	validation-rmse:6.66770
# [8]	validation-rmse:6.65334
# [9]	validation-rmse:6.64257
# [10]	validation-rmse:6.63878
# [11]	validation-rmse:6.63440
# [12]	validation-rmse:6.63002
# [13]	validation-rmse:6.62577
# [14]	validation-rmse:6.62303
# [15]	validation-rmse:6.62118
# [16]	validation-rmse:6.61821
# [17]	validation-rmse:6.61531
# [18]	validation-rmse:6.60954
# [19]	validation-rmse:6.60698
# [20]	validation-rmse:6.60451
# [21]	validation-rmse:6.60188
# [22]	validation-rmse:6.60059
# [23]	validation-rmse:6.59832
# [24]	validation-rmse:6.59626
# [25]	validation-rmse:6.59424
# [26]	validation-rmse:6.59126
# [27]	validation-rmse:6.58686
# [28]	validation-rmse:6.58342
# [29]	validation-rmse:6.57999
# [30]	validation-rmse:6.57592
# [31]	validation-rmse:6.57267
# [32]	validation-rmse:6.57120
# [33]	validation-rmse:6.56974
# [34]	validation-rmse:6.56753
# [35]	validation-rmse:6.56539
# [36]	validation-rmse:6.56424
# [37]	validation-rmse:6.56274
# [38]	validation-rmse:6.56112
# [39]	validation-rmse:6.55924
# [40]	validation-rmse:6.55647
# [41]	validation-rmse:6.55407
# [42]	validation-rmse:6.55304
# [43]	validation-rmse:6.55152
# [44]	validation-rmse:6.54966
# [45]	validation-rmse:6.54832
# [46]	validation-rmse:6.54669
# [47]	validation-rmse:6.54496
# [48]	validation-rmse:6.54264
# [49]	validation-rmse:6.54197
# [50]	validation-rmse:6.53886
# [51]	validation-rmse:6.53792
# [52]	validation-rmse:6.53622
# [53]	validation-rmse:6.53424
# [54]	validation-rmse:6.53228
# [55]	validation-rmse:6.53160
# [56]	validation-rmse:6.53063
# [57]	validation-rmse:6.52944
# [58]	validation-rmse:6.52847
# [59]	validation-rmse:6.52799
# [60]	validation-rmse:6.52648
# [61]	validation-rmse:6.52541
# [62]	validation-rmse:6.52376
# [63]	validation-rmse:6.52256
# [64]	validation-rmse:6.52198
# [65]	validation-rmse:6.52122
# [66]	validation-rmse:6.52012
# [67]	validation-rmse:6.51876
# [68]	validation-rmse:6.51786
# [69]	validation-rmse:6.51671
# [70]	validation-rmse:6.51511
# [71]	validation-rmse:6.51446
# [72]	validation-rmse:6.51325
# [73]	validation-rmse:6.51214
# [74]	validation-rmse:6.51138
# [75]	validation-rmse:6.51054
# [76]	validation-rmse:6.50641
# [77]	validation-rmse:6.50458
# [78]	validation-rmse:6.50340
# [79]	validation-rmse:6.50246
# [80]	validation-rmse:6.50228
# [81]	validation-rmse:6.50111
# [82]	validation-rmse:6.50039
# [83]	validation-rmse:6.49963
# [84]	validation-rmse:6.49830
# [85]	validation-rmse:6.49812
# [86]	validation-rmse:6.49670
# [87]	validation-rmse:6.49622
# [88]	validation-rmse:6.49491
# [89]	validation-rmse:6.49324
# [90]	validation-rmse:6.49234
# [91]	validation-rmse:6.49131
# [92]	validation-rmse:6.48985
# [93]	validation-rmse:6.48897
# [94]	validation-rmse:6.48879
# [95]	validation-rmse:6.48854
# [96]	validation-rmse:6.48802
# [97]	validation-rmse:6.48683
# [98]	validation-rmse:6.48515
# [99]	validation-rmse:6.48465
# 100%|██████████| 40/40 [01:59<00:00,  2.99s/trial, best loss: 6.379161457238043]

# %%
# Training of the best model as inferred from the mlflow ui, by choosing the model that minimizes the RMSE loss
params = {
    "learning_rate": 0.6424019772458974,
    "max_depth": 20,
    "min_child_weight": 2.2694144028711833,
    "objective": "reg:linear",
    "reg_alpha": 0.025551415216516424,
    "reg_lambda": 0.009147735459264332,
    "seed": 42,
}

# Log using autologging, which automatically logs plenty info about the run
mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=100,
    evals=[(valid, "validation")],
    early_stopping_rounds=15,
)
# Out:
# 2024/04/19 16:27:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b718c906f65f418fb57e0bc5c2b58959', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:7.79040
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [16:27:53] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:6.87496
# [2]	validation-rmse:6.67857
# [3]	validation-rmse:6.62456
# [4]	validation-rmse:6.60289
# [5]	validation-rmse:6.59332
# [6]	validation-rmse:6.57983
# [7]	validation-rmse:6.57435
# [8]	validation-rmse:6.56953
# [9]	validation-rmse:6.56221
# [10]	validation-rmse:6.55691
# [11]	validation-rmse:6.55156
# [12]	validation-rmse:6.54857
# [13]	validation-rmse:6.54374
# [14]	validation-rmse:6.53648
# [15]	validation-rmse:6.53111
# [16]	validation-rmse:6.52934
# [17]	validation-rmse:6.52656
# [18]	validation-rmse:6.52193
# [19]	validation-rmse:6.51718
# [20]	validation-rmse:6.51076
# [21]	validation-rmse:6.50723
# [22]	validation-rmse:6.50659
# [23]	validation-rmse:6.50324
# [24]	validation-rmse:6.49680
# [25]	validation-rmse:6.49462
# [26]	validation-rmse:6.49068
# [27]	validation-rmse:6.48778
# [28]	validation-rmse:6.48296
# [29]	validation-rmse:6.48014
# [30]	validation-rmse:6.47863
# [31]	validation-rmse:6.47687
# [32]	validation-rmse:6.47484
# [33]	validation-rmse:6.47093
# [34]	validation-rmse:6.46951
# [35]	validation-rmse:6.46236
# [36]	validation-rmse:6.45919
# [37]	validation-rmse:6.45876
# [38]	validation-rmse:6.45809
# [39]	validation-rmse:6.45691
# [40]	validation-rmse:6.45468
# [41]	validation-rmse:6.45306
# [42]	validation-rmse:6.45190
# [43]	validation-rmse:6.44995
# [44]	validation-rmse:6.44883
# [45]	validation-rmse:6.44610
# [46]	validation-rmse:6.44445
# [47]	validation-rmse:6.44379
# [48]	validation-rmse:6.44285
# [49]	validation-rmse:6.44070
# [50]	validation-rmse:6.43811
# [51]	validation-rmse:6.43675
# [52]	validation-rmse:6.43552
# [53]	validation-rmse:6.43367
# [54]	validation-rmse:6.43307
# [55]	validation-rmse:6.43175
# [56]	validation-rmse:6.42876
# [57]	validation-rmse:6.42734
# [58]	validation-rmse:6.42622
# [59]	validation-rmse:6.42548
# [60]	validation-rmse:6.42419
# [61]	validation-rmse:6.42308
# [62]	validation-rmse:6.42075
# [63]	validation-rmse:6.41975
# [64]	validation-rmse:6.41853
# [65]	validation-rmse:6.41723
# [66]	validation-rmse:6.41723
# [67]	validation-rmse:6.41629
# [68]	validation-rmse:6.41530
# [69]	validation-rmse:6.41182
# [70]	validation-rmse:6.41036
# [71]	validation-rmse:6.40966
# [72]	validation-rmse:6.40918
# [73]	validation-rmse:6.40735
# [74]	validation-rmse:6.40638
# [75]	validation-rmse:6.40467
# [76]	validation-rmse:6.40374
# [77]	validation-rmse:6.40201
# [78]	validation-rmse:6.40147
# [79]	validation-rmse:6.40079
# [80]	validation-rmse:6.40004
# [81]	validation-rmse:6.39987
# [82]	validation-rmse:6.39847
# [83]	validation-rmse:6.39859
# [84]	validation-rmse:6.39754
# [85]	validation-rmse:6.39635
# [86]	validation-rmse:6.39606
# [87]	validation-rmse:6.39444
# [88]	validation-rmse:6.39281
# [89]	validation-rmse:6.39155
# [90]	validation-rmse:6.39109
# [91]	validation-rmse:6.38897
# [92]	validation-rmse:6.38724
# [93]	validation-rmse:6.38699
# [94]	validation-rmse:6.38558
# [95]	validation-rmse:6.38501
# [96]	validation-rmse:6.38346
# [97]	validation-rmse:6.38275
# [98]	validation-rmse:6.38043
# [99]	validation-rmse:6.37916
# 2024/04/19 16:28:01 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/04/19 16:28:01 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [16:28:01] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."

# %% [markdown]
# ### Model management
#
# This tracks what is happening during model training, but it does not track the model itself. This can also be done in mlflow, which has the following benefits compared to folder-based logging:
# * automated instead of manual (less error-prone)
# * reliable versioning
# * model lineage (users can retrieve how the model was trained: parameters, dataset, etc.)

# %%
# First approach at logging the model itself in mlflow: logging as an artifact
mlflow.log_artifact(MODEL_FOLDER / 'lin_reg.bin', artifact_path='models_pickle')

# %%
# Second approach: log the model inside of a run, using the appropriate mlflow API

with mlflow.start_run():
    # Training of the best model as inferred from the mlflow ui, by choosing the model that minimizes the RMSE loss
    params = {
        "learning_rate": 0.6424019772458974,
        "max_depth": 20,
        "min_child_weight": 2.2694144028711833,
        "objective": "reg:linear",
        "reg_alpha": 0.025551415216516424,
        "reg_lambda": 0.009147735459264332,
        "seed": 42,
    }
    
    mlflow.log_params(params)


    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, "validation")],
        early_stopping_rounds=15,
    )
    
    # Logging it as a model using the mlflow API for the model framework (xgboost)
    mlflow.xgboost.log_model(booster, artifact_path='models_mlflow')
    
    # Logging the preprocessor as an artifact
    # First we save it as pickle, and then we log it by referencing the path
    with open(MODEL_FOLDER / 'preprocessor.b', 'wb') as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact(MODEL_FOLDER / "preprocessor.b", artifact_path="preprocessor")
# Out:
# [0]	validation-rmse:7.79040
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:11:56] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:6.87496
# [2]	validation-rmse:6.67857
# [3]	validation-rmse:6.62456
# [4]	validation-rmse:6.60289
# [5]	validation-rmse:6.59332
# [6]	validation-rmse:6.57983
# [7]	validation-rmse:6.57435
# [8]	validation-rmse:6.56953
# [9]	validation-rmse:6.56221
# [10]	validation-rmse:6.55691
# [11]	validation-rmse:6.55156
# [12]	validation-rmse:6.54857
# [13]	validation-rmse:6.54374
# [14]	validation-rmse:6.53648
# [15]	validation-rmse:6.53111
# [16]	validation-rmse:6.52934
# [17]	validation-rmse:6.52656
# [18]	validation-rmse:6.52193
# [19]	validation-rmse:6.51718
# [20]	validation-rmse:6.51076
# [21]	validation-rmse:6.50723
# [22]	validation-rmse:6.50659
# [23]	validation-rmse:6.50324
# [24]	validation-rmse:6.49680
# [25]	validation-rmse:6.49462
# [26]	validation-rmse:6.49068
# [27]	validation-rmse:6.48778
# [28]	validation-rmse:6.48296
# [29]	validation-rmse:6.48014
# [30]	validation-rmse:6.47863
# [31]	validation-rmse:6.47687
# [32]	validation-rmse:6.47484
# [33]	validation-rmse:6.47093
# [34]	validation-rmse:6.46951
# [35]	validation-rmse:6.46236
# [36]	validation-rmse:6.45919
# [37]	validation-rmse:6.45876
# [38]	validation-rmse:6.45809
# [39]	validation-rmse:6.45691
# [40]	validation-rmse:6.45468
# [41]	validation-rmse:6.45306
# [42]	validation-rmse:6.45190
# [43]	validation-rmse:6.44995
# [44]	validation-rmse:6.44883
# [45]	validation-rmse:6.44610
# [46]	validation-rmse:6.44445
# [47]	validation-rmse:6.44379
# [48]	validation-rmse:6.44285
# [49]	validation-rmse:6.44070
# [50]	validation-rmse:6.43811
# [51]	validation-rmse:6.43675
# [52]	validation-rmse:6.43552
# [53]	validation-rmse:6.43367
# [54]	validation-rmse:6.43307
# [55]	validation-rmse:6.43175
# [56]	validation-rmse:6.42876
# [57]	validation-rmse:6.42734
# [58]	validation-rmse:6.42622
# [59]	validation-rmse:6.42548
# [60]	validation-rmse:6.42419
# [61]	validation-rmse:6.42308
# [62]	validation-rmse:6.42075
# [63]	validation-rmse:6.41975
# [64]	validation-rmse:6.41853
# [65]	validation-rmse:6.41723
# [66]	validation-rmse:6.41723
# [67]	validation-rmse:6.41629
# [68]	validation-rmse:6.41530
# [69]	validation-rmse:6.41182
# [70]	validation-rmse:6.41036
# [71]	validation-rmse:6.40966
# [72]	validation-rmse:6.40918
# [73]	validation-rmse:6.40735
# [74]	validation-rmse:6.40638
# [75]	validation-rmse:6.40467
# [76]	validation-rmse:6.40374
# [77]	validation-rmse:6.40201
# [78]	validation-rmse:6.40147
# [79]	validation-rmse:6.40079
# [80]	validation-rmse:6.40004
# [81]	validation-rmse:6.39987
# [82]	validation-rmse:6.39847
# [83]	validation-rmse:6.39859
# [84]	validation-rmse:6.39754
# [85]	validation-rmse:6.39635
# [86]	validation-rmse:6.39606
# [87]	validation-rmse:6.39444
# [88]	validation-rmse:6.39281
# [89]	validation-rmse:6.39155
# [90]	validation-rmse:6.39109
# [91]	validation-rmse:6.38897
# [92]	validation-rmse:6.38724
# [93]	validation-rmse:6.38699
# [94]	validation-rmse:6.38558
# [95]	validation-rmse:6.38501
# [96]	validation-rmse:6.38346
# [97]	validation-rmse:6.38275
# [98]	validation-rmse:6.38043
# [99]	validation-rmse:6.37916
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:11:59] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# In the above code we also logged the `DictVectorizer`: this is a preprocessor, not part of the model. It is used to generate new features from the raw data, that are then used to train the model.
#
# In the future, when we want to make predictions with the model and we are given raw data as input, we want to preprocess that data in the same way that we did with the training data. It is then essential that we log the preprocessor for future use. We log it as an artifact.

# %% [markdown]
# In order to make predictions, we load the model from mlflow. In our case there are two different "flavours" that we can use: `pyfunc` which means to load it as a generic python function, and `xgboost` which loads the model as an xgboost object (giving back the original object).

# %%
# Load model as a PyFuncModel.
logged_model = 'runs:/0ebd7485b47c43ab9b53ab72548bccde/models_mlflow'

loaded_model = mlflow.pyfunc.load_model(logged_model)

loaded_model
# Out:
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:17:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 0ebd7485b47c43ab9b53ab72548bccde

# %%
# Load model as a xgboost model
xgboost_model = mlflow.xgboost.load_model(logged_model)

xgboost_model
# Out:
# /Users/alessandro.arlandini/Documents/General DS learning/DataTalksClub/mlops-zoomcamp/venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:18:17] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
y_pred = xgboost_model.predict(valid)
y_pred[:10]
# Out:
# array([15.175811 ,  7.352664 , 17.564875 , 24.57404  ,  9.3976755,
#        17.19716  , 10.984803 ,  8.377045 ,  8.945719 , 19.10443  ],
#       dtype=float32)
